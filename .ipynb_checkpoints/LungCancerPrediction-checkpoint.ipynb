# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

# %%
data_set=pd.read_csv("Lung_Cancer_Prediction/cancer_dataset.csv")

# %%
data_set
# Out:
#      index Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0        0         P1   33       1              2            4             5
# 1        1        P10   17       1              3            1             5
# 2        2       P100   35       1              4            5             6
# 3        3      P1000   37       1              7            7             7
# 4        4       P101   46       1              6            8             7
# ..     ...        ...  ...     ...            ...          ...           ...
# 995    995       P995   44       1              6            7             7
# 996    996       P996   37       2              6            8             7
# 997    997       P997   25       2              4            5             6
# 998    998       P998   18       2              6            8             7
# 999    999       P999   47       1              6            5             6
#
# ...

# %%
selected_data=data_set.loc[:,["Patient Id","Age","Gender","Air Pollution","Alcohol use","Dust Allergy","chronic Lung Disease","Shortness of Breath"]]

# %%
selected_data.isna().sum()
# Out:
# Patient Id              0
# Age                     0
# Gender                  0
# Air Pollution           0
# Alcohol use             0
# Dust Allergy            0
# chronic Lung Disease    0
# Shortness of Breath     0
# dtype: int64

# %%
training_x_data=selected_data.loc[:900]

# %%
training_x_data
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0           P1   33       1              2            4             5
# 1          P10   17       1              3            1             5
# 2         P100   35       1              4            5             6
# 3        P1000   37       1              7            7             7
# 4         P101   46       1              6            8             7
# ..         ...  ...     ...            ...          ...           ...
# 896       P905   35       1              4            5             6
# 897       P906   27       1              2            3             4
# 898       P907   48       1              6            7             7
# 899       P908   64       1              6            8             7
# 900       P909   39       1              4            5             6
#
#      chronic Lung Disease  Shortness of Breath
# 0                       2                    2
# ...

# %%
training_y_data=data_set.loc[:900,["Level"]]

# %%
training_y_data
# Out:
#       Level
# 0       Low
# 1    Medium
# 2      High
# 3      High
# 4      High
# ..      ...
# 896  Medium
# 897  Medium
# 898    High
# 899    High
# 900  Medium
#
# [901 rows x 1 columns]

# %%
label_encoder=preprocessing.LabelEncoder()

# %%
training_x_data.loc[:,["Patient Id"]]=label_encoder.fit_transform(training_x_data["Patient Id"])

# %%
training_y_data.Level=label_encoder.fit_transform(training_y_data.Level)

# %%
training_y_data
# Out:
#      Level
# 0        1
# 1        2
# 2        0
# 3        0
# 4        0
# ..     ...
# 896      2
# 897      2
# 898      0
# 899      0
# 900      2
#
# [901 rows x 1 columns]

# %%
test_x_data=selected_data.loc[901:]

# %%
test_x_data
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 901        P91   37       2              7            7             7
# 902       P910   27       2              3            1             4
# 903       P911   73       1              5            6             6
# 904       P912   17       1              3            1             5
# 905       P913   34       1              6            7             7
# ..         ...  ...     ...            ...          ...           ...
# 995       P995   44       1              6            7             7
# 996       P996   37       2              6            8             7
# 997       P997   25       2              4            5             6
# 998       P998   18       2              6            8             7
# 999       P999   47       1              6            5             6
#
#      chronic Lung Disease  Shortness of Breath
# 901                     7                    3
# ...

# %%
test_y_data=data_set.loc[901:,["Level"]]

# %%
test_y_data.Level=label_encoder.fit_transform(test_y_data.Level)

# %%
test_y_data.Level.unique()
# Out:
# array([0, 1, 2])

# %%
model=LinearRegression()

# %%
training_x_data
# Out:
#      Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0             0   33       1              2            4             5
# 1             1   17       1              3            1             5
# 2             2   35       1              4            5             6
# 3             3   37       1              7            7             7
# 4             4   46       1              6            8             7
# ..          ...  ...     ...            ...          ...           ...
# 896         896   35       1              4            5             6
# 897         897   27       1              2            3             4
# 898         898   48       1              6            7             7
# 899         899   64       1              6            8             7
# 900         900   39       1              4            5             6
#
#      chronic Lung Disease  Shortness of Breath
# 0                       2                    2
# ...

# %%
test_x_data.loc[:,["Patient Id"]]=label_encoder.fit_transform(test_x_data["Patient Id"])

# %%
test_x_data
# Out:
#     Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 901          0   37       2              7            7             7
# 902          1   27       2              3            1             4
# 903          2   73       1              5            6             6
# 904          3   17       1              3            1             5
# 905          4   34       1              6            7             7
# ..         ...  ...     ...            ...          ...           ...
# 995         94   44       1              6            7             7
# 996         95   37       2              6            8             7
# 997         96   25       2              4            5             6
# 998         97   18       2              6            8             7
# 999         98   47       1              6            5             6
#
#      chronic Lung Disease  Shortness of Breath
# 901                     7                    3
# ...

# %%
model.fit(training_x_data,training_y_data)
# Out:
# LinearRegression()

# %%
predicted_data=model.predict(test_x_data)

# %%
predicted_data=predicted_data.flatten()

# %%
output=pd.DataFrame({
    "Id":test_x_data["Patient Id"],
    "Actual Level":test_y_data.Level,
    "Predicted level":predicted_data

})

# %%
output
# Out:
#      Id  Actual Level  Predicted level
# 901   0             0         0.160255
# 902   1             1         1.281467
# 903   2             2         0.980226
# 904   3             2         1.270131
# 905   4             0         0.417802
# ..   ..           ...              ...
# 995  94             0         0.635166
# 996  95             0         0.373108
# 997  96             0         0.775162
# 998  97             0         0.231291
# 999  98             0         0.545323
#
# [99 rows x 3 columns]

# %%
output['Accuracy'] = output.apply(
    lambda row: (row['Actual Level'] - row['Predicted level']) / row['Actual Level']
    if row['Actual Level'] > 0 else row['Actual Level'] - row['Predicted level'],
    axis=1
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Predicted Level'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[146], line 1
# ...

# %%
# Out:
#      Id  Actual Level  Predicted level  Accuracy
# 901   0             0         0.160255      -inf
# 902   1             1         1.281467 -0.281467
# 903   2             2         0.980226  0.509887
# 904   3             2         1.270131  0.364935
# 905   4             0         0.417802      -inf
# ..   ..           ...              ...       ...
# 995  94             0         0.635166      -inf
# 996  95             0         0.373108      -inf
# 997  96             0         0.775162      -inf
# 998  97             0         0.231291      -inf
# 999  98             0         0.545323      -inf
#
# [99 rows x 4 columns]
