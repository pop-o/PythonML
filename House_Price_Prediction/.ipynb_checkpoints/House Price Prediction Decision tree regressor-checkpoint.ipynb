# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
data_set=pd.read_csv("train.csv")

# %%
data_set.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
selected_data=data_set.loc[:,['Id','MSSubClass','LotFrontage','LotArea','SaleCondition']]

# %%
selected_data
# Out:
#         Id  MSSubClass  LotFrontage  LotArea SaleCondition
# 0        1          60         65.0     8450        Normal
# 1        2          20         80.0     9600        Normal
# 2        3          60         68.0    11250        Normal
# 3        4          70         60.0     9550       Abnorml
# 4        5          60         84.0    14260        Normal
# ...    ...         ...          ...      ...           ...
# 1455  1456          60         62.0     7917        Normal
# 1456  1457          20         85.0    13175        Normal
# 1457  1458          70         66.0     9042        Normal
# 1458  1459          20         68.0     9717        Normal
# 1459  1460          20         75.0     9937        Normal
#
# [1460 rows x 5 columns]

# %%
sns.heatmap(selected_data.isna().transpose())
# Out:
# <Axes: >

# %%
selected_data.isna().sum()/len(selected_data)
# Out:
# Id               0.000000
# MSSubClass       0.000000
# LotFrontage      0.177397
# LotArea          0.000000
# SaleCondition    0.000000
# dtype: float64

# %%
sns.boxplot(y=selected_data["LotFrontage"])
# Out:
# <Axes: ylabel='LotFrontage'>

# %%
selected_data.LotFrontage=selected_data.LotFrontage.fillna(selected_data.LotFrontage.median())

# %%
selected_data.isna().sum()
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# SaleCondition    0
# dtype: int64

# %%
from sklearn import preprocessing

# %%
selected_data.SaleCondition.unique()
# Out:
# array(['Normal', 'Abnorml', 'Partial', 'AdjLand', 'Alloca', 'Family'],
#       dtype=object)

# %%
label_encoder=preprocessing.LabelEncoder()

# %%
selected_data.SaleCondition=label_encoder.fit_transform(selected_data.SaleCondition)

# %%
selected_data
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  SaleCondition
# 0        1          60         65.0     8450              4
# 1        2          20         80.0     9600              4
# 2        3          60         68.0    11250              4
# 3        4          70         60.0     9550              0
# 4        5          60         84.0    14260              4
# ...    ...         ...          ...      ...            ...
# 1455  1456          60         62.0     7917              4
# 1456  1457          20         85.0    13175              4
# 1457  1458          70         66.0     9042              4
# 1458  1459          20         68.0     9717              4
# 1459  1460          20         75.0     9937              4
#
# [1460 rows x 5 columns]

# %%
sns.boxplot(y=selected_data.LotArea)
# Out:
# <Axes: ylabel='LotArea'>

# %%
x_train=selected_data.loc[:,:]

# %%
x_train.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  SaleCondition
# 0   1          60         65.0     8450              4
# 1   2          20         80.0     9600              4
# 2   3          60         68.0    11250              4
# 3   4          70         60.0     9550              0
# 4   5          60         84.0    14260              4

# %%
y_train=data_set.SalePrice

# %%
y_train.head(10)
# Out:
# 0    208500
# 1    181500
# 2    223500
# 3    140000
# 4    250000
# 5    143000
# 6    307000
# 7    200000
# 8    129900
# 9    118000
# Name: SalePrice, dtype: int64

# %%
test_data_set=pd.read_csv('House_Price_Prediction/test.csv')

# %%
test_data_set
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
selected_test_data=test_data_set.loc[:,['Id','MSSubClass','LotFrontage','LotArea','SaleCondition']]

# %%
selected_test_data
# Out:
#         Id  MSSubClass  LotFrontage  LotArea SaleCondition
# 0     1461          20         80.0    11622        Normal
# 1     1462          20         81.0    14267        Normal
# 2     1463          60         74.0    13830        Normal
# 3     1464          60         78.0     9978        Normal
# 4     1465         120         43.0     5005        Normal
# ...    ...         ...          ...      ...           ...
# 1454  2915         160         21.0     1936        Normal
# 1455  2916         160         21.0     1894       Abnorml
# 1456  2917          20        160.0    20000       Abnorml
# 1457  2918          85         62.0    10441        Normal
# 1458  2919          60         74.0     9627        Normal
#
# [1459 rows x 5 columns]

# %%
selected_test_data.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      227
# LotArea            0
# SaleCondition      0
# dtype: int64

# %%
sns.heatmap(selected_test_data.isna().transpose())
# Out:
# <Axes: >

# %%
sns.boxplot(y=selected_test_data.LotFrontage)
# Out:
# <Axes: ylabel='LotFrontage'>

# %%
selected_test_data.LotFrontage=selected_test_data.LotFrontage.fillna(selected_test_data.LotFrontage.median())

# %%
selected_test_data
# Out:
#         Id  MSSubClass  LotFrontage  LotArea SaleCondition
# 0     1461          20         80.0    11622        Normal
# 1     1462          20         81.0    14267        Normal
# 2     1463          60         74.0    13830        Normal
# 3     1464          60         78.0     9978        Normal
# 4     1465         120         43.0     5005        Normal
# ...    ...         ...          ...      ...           ...
# 1454  2915         160         21.0     1936        Normal
# 1455  2916         160         21.0     1894       Abnorml
# 1456  2917          20        160.0    20000       Abnorml
# 1457  2918          85         62.0    10441        Normal
# 1458  2919          60         74.0     9627        Normal
#
# [1459 rows x 5 columns]

# %%
selected_test_data.SaleCondition=label_encoder.fit_transform(selected_test_data.SaleCondition)

# %%
selected_test_data.head()
# Out:
#      Id  MSSubClass  LotFrontage  LotArea  SaleCondition
# 0  1461          20         80.0    11622              4
# 1  1462          20         81.0    14267              4
# 2  1463          60         74.0    13830              4
# 3  1464          60         78.0     9978              4
# 4  1465         120         43.0     5005              4

# %%
x_test=selected_test_data

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predicted_y=model.predict(x_test)

# %%
predicted_y
# Out:
# array([191086.36540214, 195827.88516607, 191545.3969204 , ...,
#        226858.07227108, 173152.06511288, 182183.1920918 ])

# %%
output=pd.DataFrame({
    "Id":x_test["Id"],
    "Sale Price":predicted_y
})
# Out:
#   Cell In[206], line 3
#     "Sale Price":.2fpredicted_y
#                   ^
# SyntaxError: invalid decimal literal

# %%
output
# Out:
#         Id     Sale Price
# 0     1461  191086.365402
# 1     1462  195827.885166
# 2     1463  191545.396920
# 3     1464  190275.488572
# 4     1465  152467.021177
# ...    ...            ...
# 1454  2915  125534.430239
# 1455  2916   70250.166237
# 1456  2917  226858.072271
# 1457  2918  173152.065113
# 1458  2919  182183.192092
#
# [1459 rows x 2 columns]
