# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
data_set=pd.read_csv("diabetes_prediction_dataset.csv")

# %%
training_data=data_set.loc[:89999]

# %%
testing_data=data_set.loc[90000:]

# %%
training_data.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
label_encoder=preprocessing.LabelEncoder()

# %%
testing_data.loc[:,["ogender"]]=testing_data["gender"]
testing_data.loc[:,["osmokingh"]]=testing_data["smoking_history"]

# %%
training_data.loc[:,["gender"]]=label_encoder.fit_transform(training_data.gender)

# %%
testing_data.loc[:,["gender"]]=label_encoder.fit_transform(testing_data.gender)

# %%
training_data.loc[:,["smoking_history"]]=label_encoder.fit_transform(training_data.smoking_history)

# %%
testing_data.loc[:,["smoking_history"]]=label_encoder.fit_transform(testing_data.smoking_history)

# %%
x_train=training_data.loc[:,training_data.columns!='diabetes']

# %%
x_train.head()
# Out:
#   gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      0  80.0             0              1               4  25.19
# 1      0  54.0             0              0               0  27.32
# 2      1  28.0             0              0               4  27.32
# 3      0  36.0             0              0               1  23.45
# 4      1  76.0             1              1               1  20.14
#
#    HbA1c_level  blood_glucose_level
# 0          6.6                  140
# 1          6.6                   80
# 2          5.7                  158
# 3          5.0                  155
# 4          4.8                  155

# %%
y_train=training_data.loc[:,['diabetes']]

# %%
y_train
# Out:
#        diabetes
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 89995         0
# 89996         0
# 89997         1
# 89998         0
# 89999         0
#
# [90000 rows x 1 columns]

# %%
testing_data
# Out:
#       gender   age  hypertension  heart_disease smoking_history    bmi  \
# 90000      1  56.0             1              0               4  31.77
# 90001      0  63.0             0              0               5  27.32
# 90002      0  68.0             0              0               4  27.32
# 90003      1  13.0             0              0               0  27.32
# 90004      1  18.0             0              0               4  27.32
# ...      ...   ...           ...            ...             ...    ...
# 99995      0  80.0             0              0               0  27.32
# 99996      0   2.0             0              0               0  17.37
# 99997      1  66.0             0              0               3  27.83
# 99998      0  24.0             0              0               4  35.42
# 99999      0  57.0             0              0               1  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes ogender    osmokingh
# 90000          6.1                  140         0    Male        never
# 90001          6.6                   90         0  Female  not current
# 90002          8.2                  260         1  Female        never
# 90003          4.8                  158         0    Male      No Info
# 90004          6.0                  145         0    Male        never
# ...            ...                  ...       ...     ...          ...
# 99995          6.2                   90         0  Female      No Info
# 99996          6.5                  100         0  Female      No Info
# 99997          5.7                  155         0    Male       former
# 99998          4.0                  100         0  Female        never
# 99999          6.6                   90         0  Female      current
#
# [10000 rows x 11 columns]

# %%
x_test=testing_data.loc[:,["gender","age","hypertension","heart_disease","smoking_history","bmi","HbA1c_level","blood_glucose_level"]]

# %%
x_test
# Out:
#       gender   age  hypertension  heart_disease smoking_history    bmi  \
# 90000      1  56.0             1              0               4  31.77
# 90001      0  63.0             0              0               5  27.32
# 90002      0  68.0             0              0               4  27.32
# 90003      1  13.0             0              0               0  27.32
# 90004      1  18.0             0              0               4  27.32
# ...      ...   ...           ...            ...             ...    ...
# 99995      0  80.0             0              0               0  27.32
# 99996      0   2.0             0              0               0  17.37
# 99997      1  66.0             0              0               3  27.83
# 99998      0  24.0             0              0               4  35.42
# 99999      0  57.0             0              0               1  22.43
#
#        HbA1c_level  blood_glucose_level
# 90000          6.1                  140
# 90001          6.6                   90
# 90002          8.2                  260
# 90003          4.8                  158
# 90004          6.0                  145
# ...            ...                  ...
# 99995          6.2                   90
# 99996          6.5                  100
# 99997          5.7                  155
# 99998          4.0                  100
# 99999          6.6                   90
#
# [10000 rows x 8 columns]

# %%
y_test=testing_data.loc[:,["diabetes"]]

# %%
y_test
# Out:
#        diabetes
# 90000         0
# 90001         0
# 90002         1
# 90003         0
# 90004         0
# ...         ...
# 99995         0
# 99996         0
# 99997         0
# 99998         0
# 99999         0
#
# [10000 rows x 1 columns]

# %%
model=LinearRegression()

# %%
y_train=y_train.values.flatten()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
predicted_output=model.predict(x_test)

# %%
predicted_output=predicted_output.flatten()

# %%
predicted_output
# Out:
# array([ 0.2691931 ,  0.08197962,  0.6011222 , ...,  0.17090947,
#        -0.12919797,  0.0441214 ])

# %%
output=pd.DataFrame({
    "gender":testing_data["ogender"],
    "age":x_test["age"],
    "hypertension":x_test["hypertension"],
    "heart_disease":x_test["heart_disease"],
    "smoking_history":testing_data["osmokingh"],
    "bmi":x_test["bmi"],
    "HbA1c_level":x_test["HbA1c_level"],
    "blood_glucose_level":x_test["blood_glucose_level"],
    "Actual Diabetes chance":y_test["diabetes"],
    "Predicted Diabetes Chance":predicted_output
    
    
})

# %%
output["error"]=output["Actual Diabetes chance"]-output["Predicted Diabetes Chance"]
output["sqerr"]=output["error"]**2
output["rms"]=np.sqrt(output["sqerr"])

# %%
overallrms=np.sqrt(output["rms"].mean())

# %%
print("The accuracy of the system is: ",overallrms)
# Out:
# The accuracy of the system is:  0.39355811489913123

# %%
output.to_csv("Diabetes Prediction_LogisticRegeression.csv",index=False)

# %%
sns.scatterplot(output,x="Actual Diabetes chance",y="Predicted Diabetes Chance")
# Out:
# <Axes: xlabel='Actual Diabetes chance', ylabel='Predicted Diabetes Chance'>

# %%
from sklearn import metrics

# %%
# metrics.accuracy_score(y_test,predicted_output)

# %%
index=range(1,10001)

# %%
index
# Out:
# range(1, 10001)

# %%
output["index"]=index

# %%
output
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 90000    Male  56.0             1              0           never  31.77
# 90001  Female  63.0             0              0     not current  27.32
# 90002  Female  68.0             0              0           never  27.32
# 90003    Male  13.0             0              0         No Info  27.32
# 90004    Male  18.0             0              0           never  27.32
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  Actual Diabetes chance  \
# 90000          6.1                  140                       0
# 90001          6.6                   90                       0
# 90002          8.2                  260                       1
# 90003          4.8                  158                       0
# 90004          6.0                  145                       0
# ...            ...                  ...                     ...
# 99995          6.2                   90                       0
# 99996          6.5                  100                       0
# 99997          5.7                  155                       0
# 99998          4.0                  100                       0
# 99999          6.6                   90                       0
#
#        Predicted Diabetes Chance     error     sqerr       rms  index
# 90000                   0.269193 -0.269193  0.072465  0.269193      1
# 90001                   0.081980 -0.081980  0.006721  0.081980      2
# 90002                   0.601122  0.398878  0.159104  0.398878      3
# 90003                   0.022371 -0.022371  0.000500  0.022371      4
# 90004                   0.106676 -0.106676  0.011380  0.106676      5
# ...                          ...       ...       ...       ...    ...
# 99995                   0.061260 -0.061260  0.003753  0.061260   9996
# 99996                  -0.040519  0.040519  0.001642  0.040519   9997
# 99997                   0.170909 -0.170909  0.029210  0.170909   9998
# 99998                  -0.129198  0.129198  0.016692  0.129198   9999
# 99999                   0.044121 -0.044121  0.001947  0.044121  10000
#
# [10000 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,6))
sns.lineplot(output,x="index",y="Actual Diabetes chance",label="ACtual diabetes chance",color='blue')
sns.lineplot(output,x="index",y="Predicted Diabetes Chance",label="predicted diabetes chance",color='yellow')
plt.ylabel('Diabetes chance')
plt.title('Diabetes prediction Linear regression')
plt.xlim(0,200)
# Out:
# (0.0, 200.0)
